# %% [markdown]
# # Task 3 - Exploratory Data Analysis - Retail
#
#
# ### Objective:-
# #### *Finding out the weak areas where you can work to make more profit*.
# #### *What all business problems you can derive by exploring the data?*
#
#
#
# ### Author - Ashutosh Panda

# %%
#importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the datasetaaaa
ss = pd.read_csv("SampleSuperstore.csv")


#checking the first 10 values of the dataset
ss.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
#checking the last 5 values of the dataset
ss.tail(5)
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
#checking the shape of the dataset
ss.shape
# Out:
# (9994, 13)

# %%
#checking the columns of the dataset
ss.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
#checking the data types 
ss.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
#counting the number of values in each column


ss.count()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %%
#finding the statistical summary of the dataset

ss.info()

ss.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# ...

# %%
#finding out any missing value or null value

ss.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
#checking for duplicates
ss.duplicated().sum()
# Out:
# 17

# %%
#dropping the duplicates

ss.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
ss.duplicated().sum()
# Out:
# 17

# %%
#unique values in each column
ss.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
print(f"Ship Mode unique values are :- {ss['Ship Mode'].unique()} \n\n")



print(f"Segment unique values are :- {ss['Segment'].unique()} \n\n")

print(f"Category unique values are :- {ss['Category'].unique()} \n\n")

print(f"Region unique values are :- {ss['Region'].unique()} \n\n")

print(f"Sub category unique values are :- {ss['Sub-Category'].unique()} \n\n")
# Out:
# Ship Mode unique values are :- ['Second Class' 'Standard Class' 'First Class' 'Same Day']
#
#
# Segment unique values are :- ['Consumer' 'Corporate' 'Home Office']
#
#
# Category unique values are :- ['Furniture' 'Office Supplies' 'Technology']
#
#
# Region unique values are :- ['South' 'West' 'Central' 'East']
#
#
# Sub category unique values are :- ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']

# %%
f,ax = plt.subplots(figsize=(19,11))
sns.heatmap(ss.corr(),annot=True)
plt.show()

# %%
#checking the outliers
sns.boxplot(x = ss['Sales'])

# %%
sns.boxplot(x = ss['Profit'])

# %%
sns.boxplot(x = ss['Quantity'])

# %%
#plotting a pairplot 
sns.pairplot(ss)

# %%
plt.figure(figsize=(20,6))
plt.bar('Sub-Category','Category',data =ss)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Category", size = 20)
# Out:
# Text(0, 0.5, 'Category')

# %%
plt.figure(figsize=(20,6))
plt.bar('Sub-Category','Sales',data =ss)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Sales", size = 20)
# Out:
# <BarContainer object of 9994 artists>

# %%
plt.figure(figsize=(20,6))
plt.bar('Sub-Category','Profit',data =ss)
plt.xlabel("Sub- Category" ,size = 20)
plt.ylabel("Profit", size = 20)
# Out:
# <BarContainer object of 9994 artists>

# %%
plt.figure(figsize=(20,6))
ss.groupby('Region')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# <ipython-input-24-a6c82cc94342>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ss.groupby('Region')['Profit' , 'Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize=(100,100))
ss.groupby('State')['Profit' , 'Sales'].agg(['sum']).plot.bar()
plt.show()
# Out:
# <ipython-input-66-16f0ed07d802>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ss.groupby('State')['Profit' , 'Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize=(60,20))
ss.groupby('Region')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# <ipython-input-26-51128ed7f707>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ss.groupby('Region')['Profit' , 'Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize=(60,20))
ss.groupby('Sub-Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# <ipython-input-27-aad57bb27f14>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ss.groupby('Sub-Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()

# %%
plt.figure(figsize=(60,20))
ss.groupby('Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()
# Out:
# <ipython-input-28-82305891cc42>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   ss.groupby('Category')['Profit' , 'Sales'].agg(['sum']).plot.bar()

# %%
sns.countplot(x = ss['Segment'])

# %%
sns.countplot(x = ss['Region'])

# %%
plt.figure(figsize = (30,10))
sns.barplot(x = ss['Sub-Category'], y = ss['Profit'])

# %%
ss.hist(bins = 50, figsize=(20,16))
plt.show()

# %%
figsize = (20,16)

sns.pairplot(ss,hue = "Sub-Category")

# %%
plt.figure(figsize=(15,10))
plt.scatter(ss['Sales'], ss['Profit'])
plt.xlabel("Sales",size=20)
plt.ylabel("Profit",size=20)
# Out:
# Text(0, 0.5, 'Profit')

# %%
sns.distplot(ss['Sales'],hist = True)

# %%
textprops  = {"fontsize" : 12}
plt.title("Category")
plt.pie(ss['Category'].value_counts(), labels = ss['Category'].value_counts().index, autopct='%1.1f%%', textprops = textprops)
# Out:
# ([<matplotlib.patches.Wedge at 0x2515ad8b9d0>,
# ...
#  [Text(-0.3496380660429372, 1.0429540846910543, 'Office Supplies'),
#   Text(-0.27974354545119656, -1.0638343615330323, 'Furniture'),
#   Text(0.9197467277963864, -0.6033787837733774, 'Technology')],
#  [Text(-0.1907116723870566, 0.5688840461951205, '60.3%'),
#   Text(-0.15258738842792538, -0.5802732881089266, '21.2%'),
#   Text(0.5016800333434834, -0.32911570024002396, '18.5%')])

# %%
ss.groupby("State").Profit.agg(["mean","sum","min","max", "count", "median", "std", "var"])
# Out:
#                             mean         sum        min        max  count  \
# State
# Alabama                94.865989   5786.8253     0.0000  1459.2000     61
# Arizona               -15.303235  -3427.9246  -814.4832   211.4955    224
# Arkansas               66.811452   4008.6871     1.4190   843.1706     60
# California             38.171608  76381.3871  -325.5720  1906.4850   2001
# Colorado              -35.867351  -6527.8579 -3399.9800   247.9960    182
# Connecticut            42.823071   3511.4918   -15.5826   294.6710     82
# Delaware              103.930988   9977.3748   -48.7839  5039.9856     96
# District of Columbia  105.958930   1059.5893     4.4344   648.5624     10
# Florida                -8.875461  -3399.3017 -1811.0784   327.5922    383
# Georgia                88.315453  16250.0433     0.1134  3177.4750    184
# Idaho                  39.367767    826.7231     1.1151   259.5297     21
# Illinois              -25.625787 -12607.8870 -2929.4845   874.9875    492
# ...

# %% [markdown]
# # Observations
# ### 1. The dataset with respect to sales and profit has no outliers but quantity column does have.
# ### 2. Profit has a strong correlation with sales and profit but there is a negative correlation with discount.
# ### 3. More sales is noticed in states like California, New York and Texas so there would be definitely  more profits.
# ### 4. There is little or no sale of fastners or art supplies, so that can be limited.
# ### 5. Office supplies are most sold.
# ### 6. The region of west is doing well than south.
# ### 7. Copiers and machinery can be more sold
# ### 8. The company can do well and better by reducing expenses and concentrating on sale of office supplies and furniture.
